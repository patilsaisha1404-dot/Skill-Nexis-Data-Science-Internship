# %%
# ============================================================
# SKILLNEXIS DATA SCIENCE INTERNSHIP
# WEEK 1 - EXCEL & DATA CLEANING
# PRACTICE QUESTIONS
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# ============================================================
# LOAD DATASET
# ============================================================

# Find Excel files inside the current Week-1 folder
excel_files = list(Path.cwd().rglob("*.xlsx"))

print("Excel files found:")

for file in excel_files:
    print(file)

# Find Global Superstore dataset
file_path = None

for file in excel_files:
    if "superstore" in file.name.lower():
        file_path = file
        break

if file_path is None:
    raise FileNotFoundError(
        "Global Superstore Excel dataset was not found. "
        "Make sure the Excel file is inside the Week-1 folder."
    )

print("\nDataset selected:")
print(file_path)

# Load Orders sheet
df = pd.read_excel(file_path, sheet_name="Orders")

print("\n" + "=" * 60)
print("DATASET LOADED SUCCESSFULLY")
print("=" * 60)

print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

print("\nColumn names:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Excel files found:
# c:\Users\SAINATH\OneDrive\Desktop\SkillNexis-Data-Science-Internship\Week-1\global_superstore_2016.xlsx
#
# Dataset selected:
# c:\Users\SAINATH\OneDrive\Desktop\SkillNexis-Data-Science-Internship\Week-1\global_superstore_2016.xlsx
#
# ============================================================
# DATASET LOADED SUCCESSFULLY
# ============================================================
# Number of rows: 51290
# Number of columns: 24
#
# Column names:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City', 'State', 'Country', 'Region', 'Market', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost', 'Order Priority']
#
# First 5 rows:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# 0  ...  TEC-PH-5816  Technology       Phones
# 1  ...  FUR-CH-5379   Furniture       Chairs
# 2  ...  TEC-PH-5356  Technology       Phones
# 3  ...  TEC-PH-5267  Technology       Phones
# 4  ...  TEC-CO-6011  Technology      Copiers
#
#                                 Product Name     Sales Quantity Discount  \
# 0                           Samsung Convoy 3   221.980        2      0.0
# 1  Novimex Executive Leather Armchair, Black  3709.395        9      0.1
# 2          Nokia Smart Phone, with Caller ID  5175.171        9      0.1
# 3             Motorola Smart Phone, Cordless  2892.510        5      0.1
# 4             Sharp Wireless Fax, High-Speed  2832.960        8      0.0
#
#      Profit  Shipping Cost  Order Priority
# 0   62.1544          40.77            High
# 1 -288.7650         923.63        Critical
# 2  919.9710         915.49          Medium
# 3  -96.5400         910.16          Medium
# 4  311.5200         903.04        Critical
#
# [5 rows x 24 columns]

# %%
# ============================================================
# BASIC DATASET INFORMATION
# ============================================================

print("Dataset Shape:")
print(df.shape)

print("\nData Types:")
print(df.dtypes)

print("\nDataset Information:")
df.info()

print("\nStatistical Summary:")
display(df.describe())
# Out:
# Dataset Shape:
# (51290, 24)
#
# Data Types:
# Row ID                     int64
# Order ID                     str
# Order Date        datetime64[us]
# Ship Date         datetime64[us]
# Ship Mode                    str
# Customer ID                  str
# Customer Name                str
# Segment                      str
# Postal Code              float64
# City                         str
# State                        str
# Country                      str
# Region                       str
# Market                       str
# Product ID                   str
# Category                     str
# Sub-Category                 str
# Product Name                 str
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority               str
# dtype: object
#
# Dataset Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  str
#  2   Order Date      51290 non-null  datetime64[us]
#  3   Ship Date       51290 non-null  datetime64[us]
#  4   Ship Mode       51290 non-null  str
#  5   Customer ID     51290 non-null  str
#  6   Customer Name   51290 non-null  str
#  7   Segment         51290 non-null  str
#  8   Postal Code     9994 non-null   float64
#  9   City            51290 non-null  str
#  10  State           51290 non-null  str
#  11  Country         51290 non-null  str
#  12  Region          51290 non-null  str
#  13  Market          51290 non-null  str
#  14  Product ID      51290 non-null  str
#  15  Category        51290 non-null  str
#  16  Sub-Category    51290 non-null  str
#  17  Product Name    51290 non-null  str
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  str
# dtypes: datetime64[us](2), float64(5), int64(2), str(15)
# memory usage: 9.4 MB
#
# Statistical Summary:
#             Row ID                  Order Date                   Ship Date  \
# count  51290.00000                       51290                       51290
# mean   25645.50000  2014-05-11 21:26:49.155780  2014-05-15 20:42:42.745174
# min        1.00000         2012-01-01 00:00:00         2012-01-03 00:00:00
# 25%    12823.25000         2013-06-19 00:00:00         2013-06-23 00:00:00
# 50%    25645.50000         2014-07-08 00:00:00         2014-07-12 00:00:00
# 75%    38467.75000         2015-05-22 00:00:00         2015-05-26 00:00:00
# max    51290.00000         2015-12-31 00:00:00         2016-01-07 00:00:00
# std    14806.29199                         NaN                         NaN
#
#         Postal Code         Sales      Quantity      Discount        Profit  \
# count   9994.000000  51290.000000  51290.000000  51290.000000  51290.000000
# mean   55190.379428    246.490581      3.476545      0.142908     28.610982
# min     1040.000000      0.444000      1.000000      0.000000  -6599.978000
# 25%    23223.000000     30.758625      2.000000      0.000000      0.000000
# 50%    56430.500000     85.053000      3.000000      0.000000      9.240000
# 75%    90008.000000    251.053200      5.000000      0.200000     36.810000
# max    99301.000000  22638.480000     14.000000      0.850000   8399.976000
# std    32063.693350    487.565361      2.278766      0.212280    174.340972
#
#        Shipping Cost
# count   51290.000000
# mean       26.478567
# min         1.002000
# 25%         2.610000
# 50%         7.790000
# 75%        24.450000
# max       933.570000
# std        57.251373

# %%
# ============================================================
# PRACTICE QUESTION 1
# REMOVE DUPLICATES
# ============================================================

duplicate_count = df.duplicated().sum()

print("Number of duplicate rows:", duplicate_count)

if duplicate_count > 0:
    print("\nRemoving duplicate rows...")
    df = df.drop_duplicates().copy()
    print("Duplicates removed successfully.")
else:
    print("No duplicate rows found.")
    
print("\nRows after duplicate removal:", len(df))
# Out:
# Number of duplicate rows: 0
# No duplicate rows found.
#
# Rows after duplicate removal: 51290

# %%
# ============================================================
# CHECK MISSING VALUES
# ============================================================

missing_values = df.isnull().sum()

print("Missing values in each column:")
display(missing_values[missing_values > 0])

total_missing = df.isnull().sum().sum()

print("\nTotal missing values:", total_missing)
# Out:
# Missing values in each column:
# Postal Code    41296
# dtype: int64
# Total missing values: 41296

# %%
# ============================================================
# HANDLE MISSING VALUES
# ============================================================

# Numeric columns
numeric_columns = df.select_dtypes(include=np.number).columns

for column in numeric_columns:
    if df[column].isnull().sum() > 0:
        df[column] = df[column].fillna(df[column].median())

# Categorical/text columns
categorical_columns = df.select_dtypes(include=["object"]).columns

for column in categorical_columns:
    if df[column].isnull().sum() > 0:
        mode_value = df[column].mode()

        if not mode_value.empty:
            df[column] = df[column].fillna(mode_value[0])
        else:
            df[column] = df[column].fillna("Unknown")

print("Missing values handled successfully!")

print("\nRemaining missing values:")
display(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# Missing values handled successfully!
#
# Remaining missing values:
# C:\Users\SAINATH\AppData\Local\Temp\ipykernel_7020\1029852587.py:13: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_columns = df.select_dtypes(include=["object"]).columns
# Series([], dtype: int64)

# %%
# ============================================================
# SAVE CLEANED DATA
# ============================================================

cleaned_file = Path.cwd() / "cleaned_sales_data.csv"

df.to_csv(cleaned_file, index=False)

print("Cleaned dataset saved as:")
print(cleaned_file)
# Out:
# Cleaned dataset saved as:
# c:\Users\SAINATH\OneDrive\Desktop\SkillNexis-Data-Science-Internship\Week-1\cleaned_sales_data.csv

# %%
# ============================================================
# PRACTICE QUESTION 2
# REGION-WISE SALES PIVOT TABLE
# ============================================================

region_pivot = pd.pivot_table(
    df,
    index="Region",
    values="Sales",
    aggfunc="sum"
)

region_pivot = region_pivot.sort_values(
    by="Sales",
    ascending=False
)

print("REGION-WISE SALES")
print("=" * 50)

display(region_pivot)
# Out:
# REGION-WISE SALES
# ==================================================
#                           Sales
# Region
# Western Europe     1.731930e+06
# Central America    1.223101e+06
# Oceania            1.100185e+06
# Southeastern Asia  8.844232e+05
# Southern Asia      8.665727e+05
# Eastern Asia       8.550594e+05
# Western US         7.254578e+05
# Eastern US         6.787812e+05
# Northern Europe    6.367792e+05
# South America      6.172237e+05
# Southern Europe    6.085940e+05
# Central US         5.012399e+05
# Southern US        3.917219e+05
# Caribbean          3.242809e+05
# Western Asia       3.171070e+05
# Eastern Europe     3.100334e+05
# North Africa       2.332166e+05
# Western Africa     1.738788e+05
# Central Africa     1.436300e+05
# Eastern Africa     1.278560e+05
# Southern Africa    1.051918e+05
# Canada             6.692817e+04
# Central Asia       1.931146e+04

# %%
# ============================================================
# SAVE REGION-WISE SALES
# ============================================================

region_pivot.to_csv(
    "region_wise_sales.csv"
)

print("Region-wise sales saved as:")
print("region_wise_sales.csv")
# Out:
# Region-wise sales saved as:
# region_wise_sales.csv

# %%
# ============================================================
# PRACTICE QUESTION 3
# MEAN, MEDIAN AND MODE
# ============================================================

sales = df["Sales"]

mean_sales = sales.mean()
median_sales = sales.median()
mode_sales = sales.mode()

print("=" * 60)
print("DESCRIPTIVE STATISTICS - SALES")
print("=" * 60)

print(f"Mean Sales   : ${mean_sales:,.2f}")
print(f"Median Sales : ${median_sales:,.2f}")

if not mode_sales.empty:
    print(f"Mode Sales   : ${mode_sales.iloc[0]:,.2f}")
else:
    print("Mode Sales   : No mode found")
# Out:
# ============================================================
# DESCRIPTIVE STATISTICS - SALES
# ============================================================
# Mean Sales   : $246.49
# Median Sales : $85.05
# Mode Sales   : $12.96

# %%
# ============================================================
# VARIANCE
# ============================================================

variance_sales = sales.var()

print(f"Variance of Sales : {variance_sales:,.2f}")
# Out:
# Variance of Sales : 237,719.98

# %%
# ============================================================
# COMPLETE DESCRIPTIVE STATISTICS TABLE
# ============================================================

statistics = pd.DataFrame({
    "Statistic": [
        "Mean",
        "Median",
        "Mode",
        "Variance"
    ],
    "Value": [
        mean_sales,
        median_sales,
        mode_sales.iloc[0] if not mode_sales.empty else np.nan,
        variance_sales
    ]
})

display(statistics)
# Out:
#   Statistic          Value
# 0      Mean     246.490581
# 1    Median      85.053000
# 2      Mode      12.960000
# 3  Variance  237719.980797

# %%
# ============================================================
# PRACTICE QUESTION 4
# TOP 10 SALES
# ============================================================

top_10_sales = df.nlargest(10, "Sales").copy()

print("=" * 60)
print("TOP 10 SALES")
print("=" * 60)

display(top_10_sales[[
    "Order ID",
    "Order Date",
    "Customer Name",
    "Category",
    "Sales"
]])
# Out:
# ============================================================
# TOP 10 SALES
# ============================================================
#                        Order ID Order Date       Customer Name  \
# 47114  CA-2012-SM20320140-40985 2012-03-17         Sean Miller
# 49003  CA-2014-TC20980140-41915 2014-10-03        Tamara Chand
# 44248  CA-2015-RB19360140-42087 2015-03-24        Raymond Buch
# 49940  CA-2015-TA21385140-42300 2015-10-23        Tom Ashbrook
# 25238  CA-2015-HL15040140-42326 2015-11-18        Hunter Lopez
# 419    CA-2014-AB10105140-41991 2014-12-18       Adrian Barton
# 46295  CA-2012-SC20095140-41174 2012-09-22        Sanjit Chand
# 6422   US-2014-BS11365140-41746 2014-04-17        Bill Shonely
# 46386  CA-2014-SE20110140-41672 2014-02-02        Sanjit Engle
# 11063  CA-2014-CC12370140-41783 2014-05-24  Christopher Conant
#
#               Category      Sales
# 47114       Technology  22638.480
# 49003       Technology  17499.950
# 44248       Technology  13999.960
# 49940       Technology  11199.968
# 25238       Technology  10499.970
# 419    Office Supplies   9892.740
# 46295  Office Supplies   9449.950
# 6422        Technology   9099.930
# 46386       Technology   8749.950
# 11063       Technology   8399.976

# %%
# ============================================================
# HIGHLIGHT TOP 10 SALES
# ============================================================

top_10_display = top_10_sales[[
    "Order ID",
    "Order Date",
    "Customer Name",
    "Category",
    "Sales"
]].style.highlight_max(
    subset=["Sales"],
    color="yellow"
)

display(top_10_display)
# Out:
# <style type="text/css">
# #T_2fbb5_row0_col4 {
#   background-color: yellow;
# }
# </style>
# <table id="T_2fbb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fbb5_level0_col0" class="col_heading level0 col0" >Order ID</th>
#       <th id="T_2fbb5_level0_col1" class="col_heading level0 col1" >Order Date</th>
#       <th id="T_2fbb5_level0_col2" class="col_heading level0 col2" >Customer Name</th>
#       <th id="T_2fbb5_level0_col3" class="col_heading level0 col3" >Category</th>
#       <th id="T_2fbb5_level0_col4" class="col_heading level0 col4" >Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fbb5_level0_row0" class="row_heading level0 row0" >47114</th>
#       <td id="T_2fbb5_row0_col0" class="data row0 col0" >CA-2012-SM20320140-40985</td>
#       <td id="T_2fbb5_row0_col1" class="data row0 col1" >2012-03-17 00:00:00</td>
#       <td id="T_2fbb5_row0_col2" class="data row0 col2" >Sean Miller</td>
#       <td id="T_2fbb5_row0_col3" class="data row0 col3" >Technology</td>
#       <td id="T_2fbb5_row0_col4" class="data row0 col4" >22638.480000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row1" class="row_heading level0 row1" >49003</th>
#       <td id="T_2fbb5_row1_col0" class="data row1 col0" >CA-2014-TC20980140-41915</td>
#       <td id="T_2fbb5_row1_col1" class="data row1 col1" >2014-10-03 00:00:00</td>
#       <td id="T_2fbb5_row1_col2" class="data row1 col2" >Tamara Chand</td>
#       <td id="T_2fbb5_row1_col3" class="data row1 col3" >Technology</td>
#       <td id="T_2fbb5_row1_col4" class="data row1 col4" >17499.950000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row2" class="row_heading level0 row2" >44248</th>
#       <td id="T_2fbb5_row2_col0" class="data row2 col0" >CA-2015-RB19360140-42087</td>
#       <td id="T_2fbb5_row2_col1" class="data row2 col1" >2015-03-24 00:00:00</td>
#       <td id="T_2fbb5_row2_col2" class="data row2 col2" >Raymond Buch</td>
#       <td id="T_2fbb5_row2_col3" class="data row2 col3" >Technology</td>
#       <td id="T_2fbb5_row2_col4" class="data row2 col4" >13999.960000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row3" class="row_heading level0 row3" >49940</th>
#       <td id="T_2fbb5_row3_col0" class="data row3 col0" >CA-2015-TA21385140-42300</td>
#       <td id="T_2fbb5_row3_col1" class="data row3 col1" >2015-10-23 00:00:00</td>
#       <td id="T_2fbb5_row3_col2" class="data row3 col2" >Tom Ashbrook</td>
#       <td id="T_2fbb5_row3_col3" class="data row3 col3" >Technology</td>
#       <td id="T_2fbb5_row3_col4" class="data row3 col4" >11199.968000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row4" class="row_heading level0 row4" >25238</th>
#       <td id="T_2fbb5_row4_col0" class="data row4 col0" >CA-2015-HL15040140-42326</td>
#       <td id="T_2fbb5_row4_col1" class="data row4 col1" >2015-11-18 00:00:00</td>
#       <td id="T_2fbb5_row4_col2" class="data row4 col2" >Hunter Lopez</td>
#       <td id="T_2fbb5_row4_col3" class="data row4 col3" >Technology</td>
#       <td id="T_2fbb5_row4_col4" class="data row4 col4" >10499.970000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row5" class="row_heading level0 row5" >419</th>
#       <td id="T_2fbb5_row5_col0" class="data row5 col0" >CA-2014-AB10105140-41991</td>
#       <td id="T_2fbb5_row5_col1" class="data row5 col1" >2014-12-18 00:00:00</td>
#       <td id="T_2fbb5_row5_col2" class="data row5 col2" >Adrian Barton</td>
#       <td id="T_2fbb5_row5_col3" class="data row5 col3" >Office Supplies</td>
#       <td id="T_2fbb5_row5_col4" class="data row5 col4" >9892.740000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row6" class="row_heading level0 row6" >46295</th>
#       <td id="T_2fbb5_row6_col0" class="data row6 col0" >CA-2012-SC20095140-41174</td>
#       <td id="T_2fbb5_row6_col1" class="data row6 col1" >2012-09-22 00:00:00</td>
#       <td id="T_2fbb5_row6_col2" class="data row6 col2" >Sanjit Chand</td>
#       <td id="T_2fbb5_row6_col3" class="data row6 col3" >Office Supplies</td>
#       <td id="T_2fbb5_row6_col4" class="data row6 col4" >9449.950000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row7" class="row_heading level0 row7" >6422</th>
#       <td id="T_2fbb5_row7_col0" class="data row7 col0" >US-2014-BS11365140-41746</td>
#       <td id="T_2fbb5_row7_col1" class="data row7 col1" >2014-04-17 00:00:00</td>
#       <td id="T_2fbb5_row7_col2" class="data row7 col2" >Bill Shonely</td>
#       <td id="T_2fbb5_row7_col3" class="data row7 col3" >Technology</td>
#       <td id="T_2fbb5_row7_col4" class="data row7 col4" >9099.930000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row8" class="row_heading level0 row8" >46386</th>
#       <td id="T_2fbb5_row8_col0" class="data row8 col0" >CA-2014-SE20110140-41672</td>
#       <td id="T_2fbb5_row8_col1" class="data row8 col1" >2014-02-02 00:00:00</td>
#       <td id="T_2fbb5_row8_col2" class="data row8 col2" >Sanjit Engle</td>
#       <td id="T_2fbb5_row8_col3" class="data row8 col3" >Technology</td>
#       <td id="T_2fbb5_row8_col4" class="data row8 col4" >8749.950000</td>
#     </tr>
#     <tr>
#       <th id="T_2fbb5_level0_row9" class="row_heading level0 row9" >11063</th>
#       <td id="T_2fbb5_row9_col0" class="data row9 col0" >CA-2014-CC12370140-41783</td>
#       <td id="T_2fbb5_row9_col1" class="data row9 col1" >2014-05-24 00:00:00</td>
#       <td id="T_2fbb5_row9_col2" class="data row9 col2" >Christopher Conant</td>
#       <td id="T_2fbb5_row9_col3" class="data row9 col3" >Technology</td>
#       <td id="T_2fbb5_row9_col4" class="data row9 col4" >8399.976000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ============================================================
# SAVE TOP 10 SALES
# ============================================================

top_10_sales.to_csv(
    "top_10_sales.csv",
    index=False
)

print("Top 10 sales saved as:")
print("top_10_sales.csv")
# Out:
# Top 10 sales saved as:
# top_10_sales.csv

# %%
# ============================================================
# PRACTICE QUESTION 5
# CATEGORY-WISE REVENUE
# ============================================================

category_revenue = df.groupby(
    "Category"
)["Sales"].sum().sort_values(
    ascending=False
)

print("=" * 60)
print("CATEGORY-WISE REVENUE")
print("=" * 60)

display(category_revenue)
# Out:
# ============================================================
# CATEGORY-WISE REVENUE
# ============================================================
# Category
# Technology         4.744557e+06
# Furniture          4.110452e+06
# Office Supplies    3.787493e+06
# Name: Sales, dtype: float64

# %%
# ============================================================
# CATEGORY-WISE REVENUE BAR CHART
# ============================================================

plt.figure(figsize=(10, 6))

category_revenue.plot(
    kind="bar"
)

plt.title("Category-wise Revenue")
plt.xlabel("Category")
plt.ylabel("Total Revenue ($)")

plt.xticks(rotation=0)
plt.tight_layout()

plt.show()

# %%
# ============================================================
# SAVE CATEGORY-WISE REVENUE
# ============================================================

category_revenue.to_csv(
    "category_wise_revenue.csv"
)

print("Category-wise revenue saved successfully!")
# Out:
# Category-wise revenue saved successfully!

# %%
# ============================================================
# WEEK 1 PRACTICE SUMMARY
# ============================================================

print("=" * 70)
print("SKILLNEXIS - WEEK 1 PRACTICE QUESTIONS COMPLETED")
print("=" * 70)

print("\n1. Remove duplicates and handle missing values")
print("   Status: COMPLETED")

print("\n2. Region-wise Sales Pivot Table")
print("   Status: COMPLETED")

print("\n3. Mean, Median, Mode and Variance")
print("   Status: COMPLETED")

print("\n4. Top 10 Sales")
print("   Status: COMPLETED")

print("\n5. Category-wise Revenue Bar Chart")
print("   Status: COMPLETED")

print("\n" + "=" * 70)
print("WEEK 1 PRACTICE SET COMPLETED")
print("=" * 70)
# Out:
# ======================================================================
# SKILLNEXIS - WEEK 1 PRACTICE QUESTIONS COMPLETED
# ======================================================================
#
# 1. Remove duplicates and handle missing values
#    Status: COMPLETED
#
# 2. Region-wise Sales Pivot Table
#    Status: COMPLETED
#
# 3. Mean, Median, Mode and Variance
#    Status: COMPLETED
#
# 4. Top 10 Sales
#    Status: COMPLETED
#
# 5. Category-wise Revenue Bar Chart
#    Status: COMPLETED
#
# ======================================================================
# WEEK 1 PRACTICE SET COMPLETED
# ======================================================================
